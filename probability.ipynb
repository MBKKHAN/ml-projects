# %%
import pandas as pd

# %%
pwd
# Out:
# 'G:\\temp\\test'

# %%
url = 'NHANES.csv'
da = pd.read_csv(url)

# %%
da.shape
# Out:
# (5735, 28)

# %%
da.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
# Save it directly into the data folder you have open
da.to_csv("stat-env/data/BMX_I.csv", index=False)

# %%
url = 'stat-env/data/BMX_I.csv'
da = pd.read_csv(url)

# %%
da.shape
# Out:
# (5735, 28)

# %%
da.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
da.columns

# %%
da['BMXWT']
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 3       109.8
# 4        55.2
#         ...
# 5730     59.1
# 5731    112.1
# 5732     71.7
# 5733     78.2
# 5734     58.3
# Name: BMXWT, Length: 5735, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
x = range(da['BMXWT'].size)
y = da['BMXWT']
plt.figure(figsize=(10,5))
plt.scatter(x,y,marker='x',s=0.1)
plt.title("Weights wrt to ID'S")
plt.xlabel("ID's of Individuals")
plt.ylabel('Weights(kg)')
plt.show()

# %%
sum(y)
# Out:
# nan

# %%
z = y.dropna()

# %%
sum(z)/len(z)
# Out:
# 81.34267560889509

# %%
sum(z)
# Out:
# 460887.5999999996

# %%
B = ['bird','cat','dog', 'cat', 'bird', 'bird']
d = {'categorical':B}
df = pd.DataFrame(d)

# %%
df['categorical']
# Out:
# 0    bird
# 1     cat
# 2     dog
# 3     cat
# 4    bird
# 5    bird
# Name: categorical, dtype: object

# %%
df = pd.get_dummies(df['categorical'],prefix='category')

# %%
df
# Out:
#    category_bird  category_cat  category_dog
# 0           True         False         False
# 1          False          True         False
# 2          False         False          True
# 3          False          True         False
# 4           True         False         False
# 5           True         False         False

# %%
df.values
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False]])

# %%
gender = da['RIAGENDR']
gender.value_counts()
# Out:
# RIAGENDR
# 2    2976
# 1    2759
# Name: count, dtype: int64

# %%
da.head()
da.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
gender.value_counts().plot(kind='bar')
plt.xticks([0,1],['Male','Female'])
plt.xlabel('Gender')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import numpy as np

# %%
sizes = np.array([22, 23, 29, 32, 39, 42, 42, 42, 42, 42, 42, 42, 42, 43, 44, 46, 51, 51, 55, 55, 57, 58, 78, 83, 97, 97])

# %%
sizes.mean()
# Out:
# 49.84615384615385

# %%
from collections import Counter
cnt = Counter()
for size in sizes:
     cnt[size] += 1

cnt.most_common()
# Out:
# [(42, 8),
#  (51, 2),
#  (55, 2),
#  (97, 2),
#  (22, 1),
#  (23, 1),
#  (29, 1),
#  (32, 1),
#  (39, 1),
#  (43, 1),
#  (44, 1),
#  (46, 1),
#  (57, 1),
#  (58, 1),
#  (78, 1),
#  (83, 1)]

# %%
from scipy import stats
stats.mode(sizes)
# Out:
# ModeResult(mode=42, count=8)

# %%
gender.mode()
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender)
# Out:
# ModeResult(mode=2, count=2976)

# %%
da['HIQ210'].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
g = da['HIQ210']

# %%
g.value_counts().plot(kind='bar') #value_counts()
# Out:
# <Axes: xlabel='HIQ210'>

# %%
g.value_counts()
# Out:
# HIQ210
# 2.0    4268
# 1.0     456
# 9.0       8
# Name: count, dtype: int64

# %%
g.mode()
# Out:
# 0    2.0
# Name: HIQ210, dtype: float64

# %%
stats.mode(g)
# Out:
# ModeResult(mode=2.0, count=4268)

# %%
wt = da['BMXWT']

# %%
wt.hist(bins=6)
# Out:
# <Axes: >

# %%
plt.hist(wt,bins=7)
plt.ylabel("Frequency")
plt.xlabel("Weight")
plt.title("Frequencies according to weights")
# Out:
# Text(0.5, 1.0, 'Frequencies according to weights')

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.set(color_codes=True)
sns.set_style("white")
sns.displot(wt,bins=20,kde=True)
plt.ylabel("Frequency")
plt.xlabel("Weight")
plt.title("Frequencies according to weights")
sns.despine(offset=20,trim=True)
